# %% [markdown]
# # **React Router,Redux & Toolkit & Tailwind **
#
# **1 Create a minimal Roter with two pages. Home(/) and About(/) show the links to move bwetween pages.**
# --To create a minimal Router i used React Router. The application contains Two pages .home and About.
# I used:
# .BrowserRouter for routing
# .Routes and route for difing path.
# .Link for navigation

# %%
# %%html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Minimal React Router</title>
#
#     <script src="https://unpkg.com/react@18/umd/react.development.js"></script>
#
#     <script src="https://unpkg.com/react-router-dom@18/umd/react-dom.development.js">
#     </script>
#
#     <script src="https://unpkg.com/react-router-dom@16/umd/react-router-dom.dvelopment.js">
#     </script>
#
#     <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>
#
#     </head>
#
#     <body>
#       <div id="root"></div>
#
#       <script type="text/babel">
#       const{BrowserRouter,Routes,Route,Link}=ReactRouterDom;
#
#       function Home(){
#       return<h2>Welcome to HOME pages</h2>;
#       }
#
#       function About(){
#       return<h2>Welcome to About pages</h2>;
#       }
#
#       function App(){
#       return(
#       <BrowserRouter><div>
#       <nav>
#       <link to="/">Home</link>){""}
#
#       <link to="/about">about</link>
#       </nav>
#       <Routes>
#       <Route path="/" element={<Home/>}/>
#       <Route path="/about" element={<About/>}/>
#       </Routes>
#       </div>
#       </BrowserRouter>
#       );
#       }
#
#       const root=ReactDOM.createRoot(document.getElementById("root"));
#       root.render(<App/>);
#       </script>
#       </body>
#       </html>

# %% [markdown]
# **2 After a user click "Save",Programattically go to /thank-you**
#
# --To navigate programatically after clicking the Save button I used the useNavigate hook from ReactRouter.
#
# The useNavigate() hook allows redirection inside a function.
# When the user clicks the Save button, the function execute and calls

# %%
 <script src="https://unpkg.com/react@18/umd/react.development.js"></script>

    <script src="https://unpkg.com/react-router-dom@18/umd/react-dom.development.js">
    </script>

    <script src="https://unpkg.com/react-router-dom@16/umd/react-router-dom.dvelopment.js">
    </script>

    <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>

    </head>

    <body>
      <div id="root"></div>

      <script type="text/babel">
      const{BrowserRouter,Routes,Route,Link}=ReactRouterDom;

      function Home(){
          const navigate=useNavigate();

          cost handlesave=()=>{
              alert("Data Saved Sucessfully!");
              navigate("/thank-you");
          };

          return(
      <div>
      <h2>Welcome to HOME pages</h2>
      <button onClick={handlesave}>Save</button>

      </div>
          );
      }

      function Thankau(){
      return<h2>Thank you for submitting the form</h2>

      }
      function App(){
      return(
      <BrowserRouter>
      <Routes>
      <Route path="/" element={<Home/>}/>
      <Route path="/thank-you" element={<Thankau/>}/>
      </Routes>
      </BrowserRouter>
      );
      }
      const root=ReactDOM.createRoot(document.getElementById("root"));
      root.render(<App/>);
      </script></body>
      </html>

# %% [markdown]
# **3 Build a DashboardLayout that shows a heading and a menu . inside it, render DashboardHome at/dashboard and Setting at /deshboard/Setting.**
#
# --I created a dash boardLayout component that contains a heading and nevigation menu.
# Nested routing is implemented using the Outlet component.
#
# ./dashboard render DashboardHome
#
# ./dashboard/settings renders Setting

# %%
 <script src="https://unpkg.com/react@18/umd/react.development.js"></script>

    <script src="https://unpkg.com/react-router-dom@18/umd/react-dom.development.js">
    </script>

    <script src="https://unpkg.com/react-router-dom@16/umd/react-router-dom.dvelopment.js">
    </script>

    <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>

    </head>

    <body>
      <div id="root"></div>

      <script type="text/babel">
      const{BrowserRouter,Routes,Route,Link}=ReactRouterDom;

      function DashboardLayout(){
      return(
      <div>
      <h1>Dashboard</h1>
      <nav>
      <link to="/dashboard">Home</link>
      {""}
      <link to="/dashboard/settings">Settings</link>

      </nav>
      <Outlet/>
      </div>
      );
      }

      function DashboardHome(){
      return<h2>Welcome to Dashboard Home</h2>;
      }
      function Setting(){
      return<h2>Welcome to Setting</h2>;
      }
      function App(){
      return(
      <BrowserRouter>
      <Routes>
      <Route path="/dashboard"element={<DashboardLayout/>}>
      <Route index element={<DashboardHome/>}/>
      <Route path="settings" element={<Setting/>}/>
      </Route>
      </Routes>
      </BrowserRouter>
      );
      }
      const root=ReactDOM.createRoot(document.getElementById("root"));
      root.render(<App/>);
      </script>
      </body>
      </html>

# %% [markdown]
# **4 Create a route/users/:userId.in the UserPage component ,read the usrId from the URL and display it**
#
# --

# %%
 <script src="https://unpkg.com/react@18/umd/react.development.js"></script>

    <script src="https://unpkg.com/react-router-dom@18/umd/react-dom.development.js">
    </script>

    <script src="https://unpkg.com/react-router-dom@16/umd/react-router-dom.dvelopment.js">
    </script>

    <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>

    </head>

    <body>
      <div id="root"></div>

      <script type="text/babel">
      const{BrowserRouter,Routes,Route,Link}=ReactRouterDom;

      function UserPage(){
          cost{UsrerId}=useParams();
          return(
              <h2>UserId:{UserId}</h2>
          );

          finction App(){
      return(
          <BrowserRouter>
      <Routes>
      <Route path="/users/:userId" element={<UserPage/>}/>
      </Routes>
      </BrowserRouter>
      );
      }
          const root=ReactDOM.createRoot(document.getElementById("root"));
      root.render(<App/>);
      </script>
          </body>
          </html>

# %% [markdown]
# **expanation**
# -:userId is a dynamic parameter .
# -useParams() read the lue from URL.
# -
#
# **5 Only Logged-in users should see/dashboard. othwers should be redirected to login. write a minimal ProtectedRoute wrapper.**
# --

# %%
 <script src="https://unpkg.com/react@18/umd/react.development.js"></script>

    <script src="https://unpkg.com/react-router-dom@18/umd/react-dom.development.js">
    </script>

    <script src="https://unpkg.com/react-router-dom@16/umd/react-router-dom.dvelopment.js">
    </script>

    <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>

    </head>

    <body>
      <div id="root"></div>

      <script type="text/babel">
      const{BrowserRouter,Routes,Route,Link}=ReactRouterDom;

      const isLoggedIn=false;
      function ProtectedRoute({children}){
          if(!isLoggedIn){
              return<Navigate to="/login"/>;
          }
          function dashboard(){
              return(
                  <h2>Welcome to dashboard</h2>

          }

          function login(){
              return(<h2>please login first</h2>}

              function App(){
      return(<browserRouter>
      <Routes>
             <route path="/dashboard" element={<dashboard/>}/>
             <route path="/login" element={<login/>}/>
             <route path="*" element={<Navigate to="/login"/>}/>
      </Routes>
      </BrowserRouter>
      );}

      const root=ReactDOM.createRoot(document.getElementById("root"));
      root.render(<App/>);
      </script>
      </body>
      </html>

# %% [markdown]
# **6 Create a counter slice with increement and decreement .configure the store and provide it to React.**

# %%
 # %%html
<!DOCTYPE html>
<html>
<head>
  <title>Redux Toolkit Counter</title>

  <script src="https://unpkg.com/react@18/umd/react.development.js"></script>
  <script src="https://unpkg.com/react-dom@18/umd/react-dom.development.js"></script>
  <script src="https://unpkg.com/@reduxjs/toolkit@1.9.5/dist/redux-toolkit.umd.js"></script>
  <script src="https://unpkg.com/react-redux@8/umd/react-redux.js"></script>
  <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>
</head>

<body>
<div id="root"></div>

<script type="text/babel">
const { createSlice, configureStore } = RTK;
const { Provider, useSelector, useDispatch } = ReactRedux;

const counterSlice = createSlice({
  name: "counter",
  initialState: { value: 0 },
  reducers: {
    increment: (state) => { state.value += 1; },
    decrement: (state) => { state.value -= 1; }
  }
});

const { increment, decrement } = counterSlice.actions;

const store = configureStore({
  reducer: {
    counter: counterSlice.reducer
  }
});

function App() {
  const count = useSelector((state) => state.counter.value);
  const dispatch = useDispatch();

  return (
    <div>
      <h2>Count: {count}</h2>
      <button onClick={() => dispatch(increment())}>Increment</button>
      <button onClick={() => dispatch(decrement())}>Decrement</button>
    </div>
  );
}

const root = ReactDOM.createRoot(document.getElementById("root"));
root.render(
  <Provider store={store}>
    <App />
  </Provider>
);
</script>

</body>
</html>

# %% [markdown]
# **7 Build a Counter component that shows the value and buttoms to  to increement and decreement using Redux hooks.**

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Redux Counter Component</title>
#
#   <script src="https://unpkg.com/react@18/umd/react.development.js"></script>
#   <script src="https://unpkg.com/react-dom@18/umd/react-dom.development.js"></script>
#   <script src="https://unpkg.com/@reduxjs/toolkit@1.9.5/dist/redux-toolkit.umd.js"></script>
#   <script src="https://unpkg.com/react-redux@8/umd/react-redux.js"></script>
#   <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>
# </head>
#
# <body>
# <div id="root"></div>
#
# <script type="text/babel">
# const { createSlice, configureStore } = RTK;
# const { Provider, useSelector, useDispatch } = ReactRedux;
#
# // Counter Slice
# const counterSlice = createSlice({
#   name: "counter",
#   initialState: { value: 0 },
#   reducers: {
#     increment: (state) => { state.value += 1; },
#     decrement: (state) => { state.value -= 1; }
#   }
# });
#
# const { increment, decrement } = counterSlice.actions;
#
# // Store
# const store = configureStore({
#   reducer: {
#     counter: counterSlice.reducer
#   }
# });
#
# // Counter Component
# function Counter() {
#   const count = useSelector((state) => state.counter.value);
#   const dispatch = useDispatch();
#
#   return (
#     <div>
#       <h2>Count: {count}</h2>
#       <button onClick={() => dispatch(increment())}>Increment</button>
#       <button onClick={() => dispatch(decrement())}>Decrement</button>
#     </div>
#   );
# }
#
# // App
# function App() {
#   return <Counter />;
# }
#
# const root = ReactDOM.createRoot(document.getElementById("root"));
# root.render(
#   <Provider store={store}>
#     <App />
#   </Provider>
# );
# </script>
#
# </body>
# </html>

# %% [markdown]
# **8 Create a FetchProduct thus that loads from /api/products.handle loading and error in this slice`.**

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Redux Async Thunk Example</title>
#
#   <script src="https://unpkg.com/react@18/umd/react.development.js"></script>
#   <script src="https://unpkg.com/react-dom@18/umd/react-dom.development.js"></script>
#   <script src="https://unpkg.com/@reduxjs/toolkit@1.9.5/dist/redux-toolkit.umd.js"></script>
#   <script src="https://unpkg.com/react-redux@8/umd/react-redux.js"></script>
#   <script src="https://unpkg.com/@babel/standalone/babel.min.js"></script>
# </head>
#
# <body>
# <div id="root"></div>
#
# <script type="text/babel">
# const { createSlice, configureStore, createAsyncThunk } = RTK;
# const { Provider, useDispatch, useSelector } = ReactRedux;
#
# // Async Thunk
# const fetchProducts = createAsyncThunk(
#   "products/fetchProducts",
#   async () => {
#     const response = await fetch("https://fakestoreapi.com/products");
#     if (!response.ok) {
#       throw new Error("Failed to fetch products");
#     }
#     return await response.json();
#   }
# );
#
# // Slice
# const productSlice = createSlice({
#   name: "products",
#   initialState: {
#     items: [],
#     loading: false,
#     error: null
#   },
#   extraReducers: (builder) => {
#     builder
#       .addCase(fetchProducts.pending, (state) => {
#         state.loading = true;
#         state.error = null;
#       })
#       .addCase(fetchProducts.fulfilled, (state, action) => {
#         state.loading = false;
#         state.items = action.payload;
#       })
#       .addCase(fetchProducts.rejected, (state, action) => {
#         state.loading = false;
#         state.error = action.error.message;
#       });
#   }
# });
#
# // Store
# const store = configureStore({
#   reducer: {
#     products: productSlice.reducer
#   }
# });
#
# // Component
# function Products() {
#   const dispatch = useDispatch();
#   const { items, loading, error } = useSelector((state) => state.products);
#
#   return (
#     <div>
#       <h2>Product List</h2>
#       <button onClick={() => dispatch(fetchProducts())}>
#         Load Products
#       </button>
#
#       {loading && <p>Loading...</p>}
#       {error && <p>Error: {error}</p>}
#
#       <ul>
#         {items.map((product) => (
#           <li key={product.id}>{product.title}</li>
#         ))}
#       </ul>
#     </div>
#   );
# }
#
# // Render
# const root = ReactDOM.createRoot(document.getElementById("root"));
# root.render(
#   <Provider store={store}>
#     <Products />
#   </Provider>
# );
# </script>
#
# </body>
# </html>

# %% [markdown]
# **9 stuyle a "Buy" buttons using Tailwind . Use a blue backgrund ,white text and change the background shade on hover and focus.**

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#   <script src="https://cdn.tailwindcss.com"></script>
# </head>
# <body class="flex justify-center items-center h-screen bg-gray-100">
#
#   <button
#     class="bg-blue-500 text-white px-6 py-2 rounded-lg
#            hover:bg-blue-600 focus:bg-blue-700
#            transition duration-300">
#     Buy
#   </button>
#
# </body>
# </html>

# %% [markdown]
# **10 Create a responsive product list: on small screens one coloumn,on medium ap up, three columns and a hover a transition,also show how to reuse a utility group with @apply**
# -- I used grid and responsive classes
# Grid-cols-1 foer smmall screen
# md:grid cols-3 for midium and larger screen
# i used hover effect :scale -105 and transition for hover effect

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
#   <script src="https://cdn.tailwindcss.com"></script>
#   <style type="text/tailwindcss">
#     .product-card {
#       @apply bg-white p-4 rounded-lg shadow-md
#              hover:scale-105 transition duration-300;
#     }
#   </style>
# </head>
#
# <body class="bg-gray-100 p-6">
#
#   <div class="grid grid-cols-1 md:grid-cols-3 gap-6">
#
#     <div class="product-card">
#       <h2 class="text-lg font-bold">Product 1</h2>
#       <p class="text-gray-600">$100</p>
#     </div>
#
#     <div class="product-card">
#       <h2 class="text-lg font-bold">Product 2</h2>
#       <p class="text-gray-600">$150</p>
#     </div>
#
#     <div class="product-card">
#       <h2 class="text-lg font-bold">Product 3</h2>
#       <p class="text-gray-600">$200</p>
#     </div>
#
#   </div>
#
# </body>
# </html>
